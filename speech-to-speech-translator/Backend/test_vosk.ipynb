# %%
import sounddevice as sd
print(sd.query_devices())
# Out:
#    0 Microsoft Sound Mapper - Input, MME (2 in, 0 out)
# >  1 Microphone Array (AMD Audio Dev, MME (2 in, 0 out)
#    2 Microsoft Sound Mapper - Output, MME (0 in, 2 out)
# <  3 Speaker (Realtek(R) Audio), MME (0 in, 2 out)
#    4 Primary Sound Capture Driver, Windows DirectSound (2 in, 0 out)
#    5 Microphone Array (AMD Audio Device), Windows DirectSound (2 in, 0 out)
#    6 Primary Sound Driver, Windows DirectSound (0 in, 2 out)
#    7 Speaker (Realtek(R) Audio), Windows DirectSound (0 in, 2 out)
#    8 Speaker (Realtek(R) Audio), Windows WASAPI (0 in, 2 out)
#    9 Microphone Array (AMD Audio Device), Windows WASAPI (2 in, 0 out)
#   10 Headphones (), Windows WDM-KS (0 in, 2 out)
#   11 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Beats Flex)), Windows WDM-KS (0 in, 1 out)
#   12 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Beats Flex)), Windows WDM-KS (1 in, 0 out)
#   13 Microphone (Realtek HD Audio Mic input), Windows WDM-KS (2 in, 0 out)
#   14 Headphones 1 (Realtek HD Audio 2nd output with HAP), Windows WDM-KS (0 in, 2 out)
#   15 Headphones 2 (Realtek HD Audio 2nd output with HAP), Windows WDM-KS (0 in, 2 out)
#   16 PC Speaker (Realtek HD Audio 2nd output with HAP), Windows WDM-KS (2 in, 0 out)
#   17 Stereo Mix (Realtek HD Audio Stereo input), Windows WDM-KS (2 in, 0 out)
#   18 Speakers 1 (Realtek HD Audio output with HAP), Windows WDM-KS (0 in, 2 out)
#   19 Speakers 2 (Realtek HD Audio output with HAP), Windows WDM-KS (0 in, 2 out)
#   20 PC Speaker (Realtek HD Audio output with HAP), Windows WDM-KS (2 in, 0 out)
#   21 Speakers (), Windows WDM-KS (0 in, 2 out)
#   22 Output (@System32\drivers\bthhfenum.sys,#4;%1 Hands-Free HF Audio%0
# ;(vukkem's M33)), Windows WDM-KS (0 in, 1 out)
#   23 Input (@System32\drivers\bthhfenum.sys,#4;%1 Hands-Free HF Audio%0
# ;(vukkem's M33)), Windows WDM-KS (1 in, 0 out)
#   24 Headset Earphone (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Boom Shakalaka)), Windows WDM-KS (0 in, 1 out)
#   25 Headset Microphone (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Boom Shakalaka)), Windows WDM-KS (1 in, 0 out)
#   26 Headphones (), Windows WDM-KS (0 in, 2 out)
#   27 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(OPPO Enco Buds2)), Windows WDM-KS (0 in, 1 out)
#   28 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(OPPO Enco Buds2)), Windows WDM-KS (1 in, 0 out)
#   29 Headphones (), Windows WDM-KS (0 in, 2 out)
#   30 Headphones (), Windows WDM-KS (0 in, 2 out)
#   31 Input (), Windows WDM-KS (2 in, 0 out)
#   32 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Mivi DuoPods A750)), Windows WDM-KS (0 in, 1 out)
#   33 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Mivi DuoPods A750)), Windows WDM-KS (1 in, 0 out)
#   34 Headphones (), Windows WDM-KS (0 in, 2 out)
#   35 Headphones (), Windows WDM-KS (0 in, 2 out)
#   36 Headphones (), Windows WDM-KS (0 in, 2 out)
#   37 Microphone Array 1 (AMDAfdInstall Wave Microphone - 1), Windows WDM-KS (2 in, 0 out)
#   38 Microphone Array 2 (AMDAfdInstall Wave Microphone - 1), Windows WDM-KS (1 in, 0 out)
#   39 Headphones (), Windows WDM-KS (0 in, 2 out)
#   40 Headphones (), Windows WDM-KS (0 in, 2 out)
#   41 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Airdopes 138)), Windows WDM-KS (0 in, 1 out)
#   42 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Airdopes 138)), Windows WDM-KS (1 in, 0 out)
#   43 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(OPPO Enco Buds2)), Windows WDM-KS (0 in, 1 out)
#   44 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(OPPO Enco Buds2)), Windows WDM-KS (1 in, 0 out)
#   45 Headphones (), Windows WDM-KS (0 in, 2 out)
#   46 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Nothing Ear)), Windows WDM-KS (0 in, 1 out)
#   47 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Nothing Ear)), Windows WDM-KS (1 in, 0 out)
#   48 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(OPPO Enco Buds2)), Windows WDM-KS (0 in, 1 out)
#   49 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(OPPO Enco Buds2)), Windows WDM-KS (1 in, 0 out)
#   50 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(realme TechLife Buds T100)), Windows WDM-KS (0 in, 1 out)
#   51 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(realme TechLife Buds T100)), Windows WDM-KS (1 in, 0 out)
#   52 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(boAt Stone 1000)), Windows WDM-KS (0 in, 1 out)
#   53 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(boAt Stone 1000)), Windows WDM-KS (1 in, 0 out)
#   54 Speakers (), Windows WDM-KS (0 in, 2 out)
#   55 Headphones (), Windows WDM-KS (0 in, 2 out)
#   56 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Voora’s)), Windows WDM-KS (0 in, 1 out)
#   57 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Voora’s)), Windows WDM-KS (1 in, 0 out)
#   58 Headphones (), Windows WDM-KS (0 in, 2 out)
#   59 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Airdopes 131)), Windows WDM-KS (0 in, 1 out)
#   60 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Airdopes 131)), Windows WDM-KS (1 in, 0 out)

# %%
import os
import sounddevice as sd
import queue
import json
from vosk import Model, KaldiRecognizer

# Path to your Vosk model (change the path accordingly)
model_path = "models/vosk-model-en-us-0.22/vosk-model-en-us-0.22"

# Load model
if not os.path.exists(model_path):
    print("Model not found! Check the path.")
    exit(1)

model = Model(model_path)
recognizer = KaldiRecognizer(model, 16000)
audio_queue = queue.Queue()

def callback(indata, frames, time, status):
    if status:
        print(status, flush=True)
    audio_queue.put(bytes(indata))

# Start Recording
with sd.RawInputStream(samplerate=16000, blocksize=8000, dtype='int16',
                        channels=1, callback=callback):
    print("🎤 Speak now...")
    while True:
        data = audio_queue.get()
        if recognizer.AcceptWaveform(data):
            result = json.loads(recognizer.Result())
            print("Recognized:", result["text"])
# Out:
# 🎤 Speak now...
# Recognized: the
# Recognized: the
# Recognized: the
# Recognized: the
# Recognized: the
# Recognized: the
# Recognized: the
# Recognized: the
# Recognized: the
# Recognized: the
# Recognized: the
# Recognized: the
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 30
#      28 while True:
#      29     data = audio_queue.get()
# ---> 30     if recognizer.AcceptWaveform(data):
#      31         result = json.loads(recognizer.Result())
#      32         print("Recognized:", result["text"])
#
# File c:\Users\vukke\anaconda3\envs\tf\lib\site-packages\vosk\__init__.py:182, in KaldiRecognizer.AcceptWaveform(self, data)
#     181 def AcceptWaveform(self, data):
# --> 182     res = _c.vosk_recognizer_accept_waveform(self._handle, data, len(data))
#     183     if res < 0:
#     184         raise Exception("Failed to process waveform")
#
# KeyboardInterrupt:
